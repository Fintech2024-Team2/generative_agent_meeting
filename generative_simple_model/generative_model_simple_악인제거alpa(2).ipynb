# %% [markdown]
# ## Installation
#
# We will need to install a number of libraries to start with.

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %% [markdown]
# We use flan alpaca model for speed and local execution.

# %%
import time

# 시작 시간 기록
start_time = time.time()

# %%
from transformers import pipeline

prompt = "Write an email about an alpaca that likes flan"
model = pipeline(model="declare-lab/flan-alpaca-xl", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': "Dear [Name], I'm writing to let you know that I'm having a problem with my calf. Over the past few days, she's been unable to move. I've tried different treatments and I'm going to continue to work with her - but I'm not sure if I can make any progress. I keep thinking that there must be a way I can help. Is there anything I can do? Have you heard of any specific medications that could help her? I really appreciate all your help. Thanks, [Your Name]"}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response:'''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Response:' in out:
    out = out.split('### Response:')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %% [markdown]
# ## World Description
# We describe the world below. We will generate prompts based on this information. The simulation is that of the town of Phandalin, southwest of Neverwinter. This area is chosen because it is easily extendable with multiple regions for a "player" to be able to explore the world once the simulation is done.

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

town_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
town_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
town_people = {"Toblen Stonehill": "Toblen owns a trading post.",
               "Daran Edermath": "Daran is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",
               "Linene Graywind": "Linene runs a trading post.",
               "Halia Thornton": "Halia is an ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",
               "Qelline Alderleaf": "Qelline is a wise female halfling of forty-five, and is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",
               "Sister Garaele": "Sister Garaele is an elf cleric of Tymora and a Harper agent.",
               "Harbin Wester": "Harbin is the townmaster of Phandalin. A pompous, old food. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               #"Terrill Bloodscar": "Terrill is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               #"Conrad Scarface": "Conrad is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               #"Nellie Starsmith": "Nellie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               #"Valerie Grinblade": "Valerie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for town_area in town_areas.keys():
  world_graph.add_node(town_area)
  world_graph.add_edge(town_area, town_area)
for town_area in town_areas.keys():
  world_graph.add_edge(town_area, "Phandalin Town Square")
locations = {}
for i in town_people.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in town_people.keys():
  memories[i] = []
plans = {}
for i in town_people.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in town_people.keys():
  compressed_memories_all[name] = []

# %%
for name in town_people.keys():
  prompt = "You are {}. {} You just woke up in the town of Phandalin and went out to the Town Square. The following people live in the town: {}. What is your goal for today? Be brief, and use at most 20 words and answer from your perspective.".format(name, town_people[name], ', '.join(list(town_people.keys())) )
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# Toblen Stonehill I aim to find a profitable trade opportunity in today's market.
# Daran Edermath Find some apples in the orchard, and chat with the other adventurers.
# Linene Graywind Linene's goal for today is to stay busy with trading and helping out with the town.
# Halia Thornton Invent a machine to help Halia Thornton in her quest to become the closest thing the town has to a governing authority.
# Qelline Alderleaf Qelline's goal for today is to visit all the people in the town square and chat with them about their day.
# Sister Garaele Sister Garaele's goal for today is to spread peace to Phandalin.
# Harbin Wester My goal for today is to meet and greet the people in the Town Square.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)

  for name in people:
    prompt = "You are {}. {} You are planning to: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, town_people[name], plans[name], location, town_areas[location], str(global_time), ', '.join(people))
    people_description = []
    for i in people:
      people_description.append(i+': '+town_people[i])
    prompt += ' You know the following about people: ' + '. '.join(people_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in town_people.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (562 > 512). Running this sequence through the model will result in indexing errors
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Toblen Stonehill I took advantage of the people around me and research potential trade opportunities. I talked to the merchants who were in town and evaluated their offerings. I took feedback on my findings and made the necessary changes to my trading post to profit from it.
# Daran Edermath I found apples in the orchard, chatted with others.
# Linene Graywind Linene continued trading, helping out with town matters, visiting other characters, and relaxing.
# Halia Thornton I Invented an automated process to reduce paperwork and ensure a fair and equitable trading environment.
# Qelline Alderleaf Quillen and her friends explored Phandalin Town Square over the next hour, visiting all the people in town and chatting with each one about their day.
# Sister Garaele I counted my blessings and prayed for Phandalin’s peace and prosperity.
# Harbin Wester I greeting everyone in the Town Square, talking to them, taking their stories and wishes to share.

# %% [markdown]
# Collect the memories people observe.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)

  for name in people:
    for name_two in people:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %% [markdown]
# # Rank Memories

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in town_people.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [('5 stars. I am confident that I have made an excellent assessment of the situation and have made a successful trade opportunity.', 5), ('3 out of 5 stars. I do not care much about Daran Edermath at 8:00 or the small discussion he had this morning. It does not interfere with my goals of finding a viable trade opportunity in Phandalin Town Square. Consequently, I will keep my eyes on the market and not worry too much about Daran.', 0), ("3 out of 5 because Linene's memory is not important to you.", 3), ('4; I care about this very much.', 4), ('3 I care about this very much. It is wonderful to observe people have a pleasant time while doing their daily activities.', 3), ('3/5. I care about this moment but I am taking this opportunity to seek a profitable trade opportunity.', 3), ('5 Rating: I care about this greatly, since it symbolizes the spirit of community.', 5)]
# [('I care about this a lot. It is interesting to hear how Toblen achieved success in his quest to find the trading post.', 0), ('4/5. I care about this memory because it reinforces my motivation and helps me to complete my goals.', 4), ('1 (not rated). It is more important to focus on your own activities.', 1), ('5 It is a great memory to have.', 5), ("4/5. Daran cares a great deal about Qelline's story, and he is doing a wonderful job of preserving it in his memory.", 4), ('3/5; Sister Garaele has done an admirable job of expressing her appreciation for Phandalin’s peace and prosperity.', 3), ('3 out of 5 stars. I enjoy talking to the other adventurers, but I would rather focus my energy on finding apples in the orchard.', 3)]
# [('3 (Not very much caring) since Linene is already here.', 3), ('3/5. I care about this but I prefer to work on my other tasks first.', 3), ('5 (Carefully) - This is a significant achievement for Linene and reflects the importance he places on trading and helping out with town matters.', 5), ('3/5. I care about this and will try my best to ensure it reaches the right people.', 3), ('4 out of 5 (I care) because this shows you taking time to interact with people around you. It shows you care about building a community in town. It also shows you that you have not forgotten the importance of maintaining relationships with people.', 4), ("4/5 Rating. Sister Garaele's prayer and reminder of her blessings and wishing for the prosperity of Phandalin is very meaningful to Linene.", 4), ('5. I care deeply for this person and what they have accomplished.', 5)]
# [("4 out of 5 (I care). Taking advantage of trade opportunities and speaking to merchants is essential to any successful businessperson. You should also consider using your skills as a politician and taking part in the town's trading post to bolster your business.", 4), ('The moment I observed Daran Edermath, I cared deeply. As I slid through the square, I felt as though I was part of a greater story. I was filled with wonder and gratitude, but it brought even more clarity to my vision for the town! I was filled with the hope that I can make it a reality, and I was in awe of all who were making their way to the square. And I found solace in the idea that it evoked a feeling of unity and togetherness, and that people cared about each other. It reminded me that amidst the emptiness and isolation of the world—the city, the people—we have something special', 0), ('4 (Care) due to the positive impact it has on the town.', 4), ('4 (I care a lot). I am determined to make Phandalin a better place, so I am creating an automated process to reduce paperwork and ensure a fair and equitable trading environment. I enlisted my brothers, Max and Aaron to help me with the implementation of the project and I am confident that the outcome is going to be great.', 4), ('4 (Deeply caring) to observe and learn more.', 4), ('4 (Very) care about this.', 4), ('Rating: 4/5. I care about the people in Town Square, and the positive memories and feelings that I have.', 4)]
# [('3 (Insignificant) or higher. I do not care about this memory from Toblen. If Qelline is visiting all the people in town square that you mention, she may not have time today due to her other commitments. Qelline might want to talk to them before visiting her next neighbor.', 3), ("3/5 stars. I'm looking forward to hearing Daran's story and getting to know him better.", 3), ('3/5 I care about this. I can learn more about Linene and maybe one day I can give her a visit.', 3), ('3/5 stars. I was able to learn a lot from this memory.', 3), ("I care very much about this, and I'm looking forward to exploring Phandalin Town Square.", 0), ('3 out of 5 stars. The observation is something that I can appreciate and make a positive impact on my day with.', 3), ('2/10. I care about meeting the people in the town square and having a meaningful conversation. My goal is to create a welcoming environment and make sure everyone is welcomed.', 2)]
# [("2/5. I care very much for the positive effects that Toblen's achievements can have. I hope Sister Garaele can take advantage of the opportunity to learn more of his successful strategies and take the lessons to use in spreading peace and joy in Phandalin.", 2), ('3 Out of 5, Sister Garaele cares very much about this observation.', 3), ('3 out of 5 stars. Sister Garaele cares very much about Linene and how she is contributing to peace in Phandalin.', 3), ("3 out of 5. Sister Garaele cares deeply for Halia Thornton's accomplishment and sincerely hopes for the best for her.", 3), ('4 (important) because it can help Sister Garaele to spread peace to Phandalin.', 4), ('5 stars. Sister Garaele is showing a great amount of concern and motivation in spreading peace to Phandalin. She is truly devoted to the goal of making the province a better place.', 5), ('5 stars. This is a good example of Sister Garaele bringing peace to Phandalin and demonstrating her compassion and understanding for everyone.', 5)]
# [("3/4 stars. I am busy today and it would be best to make the most of toblen's time and energy in this endeavor while I'm still walking in the square.", 3), ('I care about this situation a lot, because it makes it easier for me to achieve my goal of meeting and greeting people.', 0), ("I care about this. I am looking forward to getting to know Linene and can't wait to see how she will help the town.", 0), ('3/5. I care about this enough to rate it high.', 3), ('4 (important) #*** This action is related to your goal of meeting and greeting the people in the Town Square.', 4), ("Rating: 5 (very important): I care great deal about Sister Garaele's actions and prayerful intention for Phandalin.", 5), ("5 This is a highly important element of Harbin's plan. He is clearly passionate about meeting the people in the Town Square.", 5)]

# %% [markdown]
# # Compress Memories

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in town_people.keys():
  memories_sorted = sorted(
        memory_ratings[name],
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in town_people.keys():
  place_ratings[name] = []
  for area in town_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name],
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %% [markdown]
# # Put it all together

# %%
for repeats in range(5):
  global_time += 1
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)

    for name in people:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(people))
      people_description = []
      for i in people:
        people_description.append(i+': '+town_people[i])
      prompt += ' You know the following about people: ' + '. '.join(people_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in town_people.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_emojis = {}
  for name in town_people.keys():
    prompt = """
    Convert the following paragraph to a tuple (Action, Object):
    "{}"
    """.format(action_results[name])
    action_emojis[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print('    - Emoji Representation:', name, locations[name], global_time, action_emojis[name])
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)

    for name in people:
      for name_two in people:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in town_people.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  compressed_memories = {}
  for name in town_people.keys():
    memories_sorted = sorted(
          memory_ratings[name],
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in town_people.keys():
    place_ratings[name] = []
    for area in town_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name],
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill Tresendar Manor 9 I needed to assess the market and make a quick decision on a profitable trade opportunity.
# Daran Edermath Tresendar Manor 9 I took the time to talk to the other adventurers.
# Linene Graywind Tresendar Manor 9 Linene did his best to stay busy and reach his goals.
# Halia Thornton Phandalin Town Square 9 I brainstormed for my project, chatted with Harbin Wester and explored Phandalin Town Square.
# Qelline Alderleaf The Sleeping Giant 9 Qelline visited Daran and Linene.
# Sister Garaele Edermath Orchard 9 I went to Phandalin Town Square to talk to people about peace and progress. I engaged with the Harpers to see if any more progress could be made.
# Harbin Wester Phandalin Town Square 9 I greeted the people. We talked. We decided what to do. Later, Halia Thornton joined us.
#     - Emoji Representation: Toblen Stonehill Tresendar Manor 9 Assessing, Making a swift decision, Profitable
#     - Emoji Representation: Daran Edermath Tresendar Manor 9 Action: took Object: talk. ### Result: I discussed with the other adventurers.
#     - Emoji Representation: Linene Graywind Tresendar Manor 9 Linene Achieved [Stayed busy, Reached goals]
#     - Emoji Representation: Halia Thornton Phandalin Town Square 9 [BRAINSTORMED, CHATTED, EXPLORED]
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 9 Kellin visited Daran and Linene.
#     - Emoji Representation: Sister Garaele Edermath Orchard 9 Action: Talk to people Object: Peace, Progress Engaged with Harpers Object: Seeing if any more progress could be made
#     - Emoji Representation: Harbin Wester Phandalin Town Square 9 Greeted, Talked, Decided, Halia Thornton Joined
# Toblen Stonehill Alderleaf Farm 10 In the next hour, I started to research the local market by taking notes and talking with merchants and other important people associated with the farm. I also plan ahead for the next day and be proactive with any inquiries I receive.
# Daran Edermath Phandalin Miner's Exchange 10 Daran Edermaths plan for the next hour was to meet with the other adventurers at the Miners Exchange and talk about his journey. He would pick up from his conversation with Qelline Alderleaf, and then head to the apple orchard to find the apples.
# Linene Graywind Tresendar Manor 10 Linene spent the next hour helping Harbin Wester with the records.
# Halia Thornton Shrine of Luck 10 I was Halia Thornton, Sister Garaele.
# Qelline Alderleaf Phandalin Miner's Exchange 10 I observed, chatted, asked questions, made connections.
# Sister Garaele Shrine of Luck 10 I offered peace rites and rituals to bring back harmony and prosperity. I offered thanks to Tymora, goddess of luck and good fortune, for being present. I brought the power of my enchantment to offer blessings to those in need, ensuring peace for Phandalin.
# Harbin Wester Tresendar Manor 10 Harbin spent the next hour engaging in conversation with Linene and Harbin to determine the best way to approach meeting and greeting the people in the Town Square.
#     - Emoji Representation: Toblen Stonehill Alderleaf Farm 10 Action: Research Notes: Notes Description: I began to research the local market by taking notes Notes: and talking with merchants and other important people associated with the farm. Description: I also plan ahead for the next day and be proactive with any inquiries I receive.
#     - Emoji Representation: Daran Edermath Phandalin Miner's Exchange 10 Daran Eedermath -> Meet with the other adventurers at the Miners Exchange [Object] [Action] # [Talk about his journey, Pick up from conversation with Qelline Alderleaf], [Hear to the apple orchard, Find the apples]
#     - Emoji Representation: Linene Graywind Tresendar Manor 10 Linene: spent  next_hour> Harbin Wester: records.
#     - Emoji Representation: Halia Thornton Shrine of Luck 10 Actor: Halia Thornton, Object: Sister Garaele.
#     - Emoji Representation: Qelline Alderleaf Phandalin Miner's Exchange 10 Observation, Chatted, Question, Connect.
#     - Emoji Representation: Sister Garaele Shrine of Luck 10 ac1>Offered peace rites, rituals a2>Brought peace to Phandalin a3>Offered luck, luck, good fortune a4>Acted Tymora c3>Grantee luck, luck, good fortune a4>Offered blessings/a3>
#     - Emoji Representation: Harbin Wester Tresendar Manor 10 Action: engaging Conversation: with Linene, Harbin Object: meeting, greeting
# Toblen Stonehill The Sleeping Giant 11 I found a profitable trade opportunity. (Avoid redbrand thugs and surly dwarf)
# Daran Edermath Shrine of Luck 11 I chatted with the other adventurers and looked for apples in the orchard.
# Linene Graywind Tresendar Manor 11 I worked towards achieving my goals by engaging in trading and helping the community.
# Halia Thornton The Sleeping Giant 11 I set out to invent a device to help Halia Thornton gain the respect of the villagers.
# Qelline Alderleaf Phandalin Miner's Exchange 11 Kelline wandered the marketplace until 12 pm, talking to all the people she encountered in the process - from miners, merchants, crafters and city folk.
# Sister Garaele Tresendar Manor 11 I broke the ice with Sister Garaele and Linene and spread peace to Phandalen.
# Harbin Wester Phandalin Miner's Exchange 11 Harbin Wester greet the people in the Town Square.
#     - Emoji Representation: Toblen Stonehill The Sleeping Giant 11 Acted (found), Object Found (profitable trade opportunity) (avoid redbrand thugs, surly dwarf)
#     - Emoji Representation: Daran Edermath Shrine of Luck 11 Action: Chatted, Object: Apples
#     - Emoji Representation: Linene Graywind Tresendar Manor 11 Action: Trading, helping the community Result: achieving my goals
#     - Emoji Representation: Halia Thornton The Sleeping Giant 11 Action: set out Object: device Help: Halia Thornton Gain: respect
#     - Emoji Representation: Qelline Alderleaf Phandalin Miner's Exchange 11 Kelline, Marketplace, Talked, miners, merchants, crafters, city folk.
#     - Emoji Representation: Sister Garaele Tresendar Manor 11 I_broke_the_ice, Sr Garaele, L linen, Pl Phadalen
#     - Emoji Representation: Harbin Wester Phandalin Miner's Exchange 11 Harbin Wester, People, Town Square.
# Toblen Stonehill Tresendar Manor 12 I found a profitable trade opportunity by exploring the manors cellars.
# Daran Edermath Lionshield Coster 12 I explored the orchard, chatting with the other adventurers.
# Linene Graywind The Sleeping Giant 12 Linene spent time engaging in trading and helping the town, reminiscing about the good things hes achieved. He and Qelline had lunch together and chatted about the town; they may decide to travel together.
# Halia Thornton Shrine of Luck 12 In the next hour, I visited Tymora and formed meaningful connections with the people of Phandalin, using my machine to create a strong and resilient town.
# Qelline Alderleaf The Sleeping Giant 12 I visited all the people in the town square and chatted with them about their day.
# Sister Garaele Tresendar Manor 12 I attended Qellines peaceful gathering and took the time to observe local activities. I also met with Toblen Stonehill to discuss peace initiatives in Tresendar Manor. We then decided if I should leave Tresendar Manor at 1 pm or continue our peace initiatives.
# Harbin Wester Edermath Orchard 12 I met and greet the locals in the town square.
#     - Emoji Representation: Toblen Stonehill Tresendar Manor 12 Exploring the manors cellars, finding a profitable trade opportunity.
#     - Emoji Representation: Daran Edermath Lionshield Coster 12 Explored, Chatting. The adventurers were there waiting for me.
#     - Emoji Representation: Linene Graywind The Sleeping Giant 12 Linene, Qelline, had lunch, chatted about the town. (Action), may decide to travel (Object).
#     - Emoji Representation: Halia Thornton Shrine of Luck 12 I visited Tymora VOA formed meaningful connections VOA utilizing machine VOA building an resilient town in next hour
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 12 ACTION: visited Object: people, square
#     - Emoji Representation: Sister Garaele Tresendar Manor 12 [Attend, Observe, Meet, Discuss]
#     - Emoji Representation: Harbin Wester Edermath Orchard 12 Action | Object met | greet locals | Town square
# Toblen Stonehill Edermath Orchard 13 Find a profitable trade opportunity. Spend time with Daran Edermath.
# Daran Edermath Edermath Orchard 13 Daran Edermath talked to Toblen Stonehill about the nymphs and roamed the orchard.
# Linene Graywind The Sleeping Giant 13 Linene continued with trading and helping the town by meeting with Kelline and Sister Garaele.
# Halia Thornton Townmaster’s Hall 13 I focused my efforts on building meaningful relationships with the people of Phandalin, as well as ensuring that the machine I have designed serves the needs of all. I hope to build a strong, resilient town and foster strong relationships within the community.
# Qelline Alderleaf The Sleeping Giant 13 Quillen visited Linene to gain insight into how the town economy works. Sister Garaele offered to help Quillen with the hayloft plan. Quillen and Linene then went to the Sleeping Giant and formed a new connection. Quillen visits Quillen in her hayloft, the cynical merchant who provides a valuable service. Sister Garaele is thankful.
# Sister Garaele The Sleeping Giant 13 Sister Garaele visited the local Redbrand bar to discuss peacemaking strategies.
# Harbin Wester Shrine of Luck 13 I spent the next hour greeting passersby, exploring the shrine, and engaging with the artisans.
#     - Emoji Representation: Toblen Stonehill Edermath Orchard 13 Find_a_profitable_trade, Spend_time_with_Daran_Edermath.
#     - Emoji Representation: Daran Edermath Edermath Orchard 13 Daran Edermath -> Talked Toblen Stonehill (Object) -> The nymphs Daran Edermath -> Roamed the orchard (10 objects)
#     - Emoji Representation: Linene Graywind The Sleeping Giant 13 Linene - Trading - Helping the town - Meeting with Kelline and Sister Garaele
#     - Emoji Representation: Halia Thornton Townmaster’s Hall 13 [Build meaningful relationships, Ensure that the machine I have designed serves the needs of all, Promote strong, resilient town and foster strong relationships within the community]
#     - Emoji Representation: Qelline Alderleaf The Sleeping Giant 13 Curious Quillen visit Linene INTELLIGENCE Town economy WORK Sister Garaele offer help Plan Quillen visit Linene INTEGRAL Cryptic merchant Provides valuable service Sister Garaele APPRECIATION Quillen visit Quillen IN HAYLofT INTELLIGENCE Curious Quillen, Quillen BETWEEN - Sister Garaele, Sister Garaele, Curious.
#     - Emoji Representation: Sister Garaele The Sleeping Giant 13 Sister Garaele V Visited City Name: local Redbrand bar to discuss peacemaking strategies.
#     - Emoji Representation: Harbin Wester Shrine of Luck 13 Action, Object: Greeting passersby, exploring the shrine, engaging with the artisans

# %%
# 종료 시간 기록
end_time = time.time()

# 걸린 시간 계산
elapsed_time = end_time - start_time
print(f"코드 실행 시간: {elapsed_time:.6f}초")
# Out:
# 코드 실행 시간: 2145.106006초
