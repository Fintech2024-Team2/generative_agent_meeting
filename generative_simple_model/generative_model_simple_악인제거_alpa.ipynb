# %% [markdown]
# ## Installation
#
# We will need to install a number of libraries to start with.

# %%
import networkx as nx
# !pip install transformers
# !pip install sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %% [markdown]
# We use flan alpaca model for speed and local execution.

# %%
from transformers import pipeline

prompt = "Write an email about an alpaca that likes flan"
model = pipeline(model="declare-lab/flan-alpaca-xl", device=0)
model(prompt, max_length=128, do_sample=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/50.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.45G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# [{'generated_text': 'Hello everyone! I recently adopted an alpaca from a pet store. He was not tame and he quickly learned to dislike all flan. It was a surprise and was so excited to see he liked it! He loves his fritters, but I decided to give him some treats as well. He loves a mix of flavors: vanilla and chocolate, and I think it was a good idea to mix it with his favorite dessert. He loves it, and we think you should try it out too! To make it, I used almond milk instead of regular milk, but you can'}]

# %%
from transformers import pipeline
import networkx as nx
prompt = '''### Instruction:
Who is the first person on the moon?

### Response:'''
def generate(prompt):
  output = model(prompt, do_sample=True, min_length=10, max_length=len(prompt)+128)
  out = output[0]['generated_text']
  if '### Response:' in out:
    out = out.split('### Response:')[1]
  if '### Instruction:' in out:
    out = out.split('### Instruction:')[0]
  return out

# %% [markdown]
# ## World Description
# We describe the world below. We will generate prompts based on this information. The simulation is that of the town of Phandalin, southwest of Neverwinter. This area is chosen because it is easily extendable with multiple regions for a "player" to be able to explore the world once the simulation is done.

# %%
world_graph = nx.Graph()

prompt_meta = '''### Instruction:
{}

### Response:'''

town_areas = ["Barthen's Provisions", "Lionshield Coster", "Stonehill Inn", "Phandalin Town Square"]
town_areas = {"Phandalin Town Square": 'Town square of the town of Phandalin.',
              'Stonehill Inn': "In the center of town stands a large, newly built roadhouse of fieldstone and rough-hewn timbers. The common room is filled with locals nursing mugs of ale or cider, all of them eyeing you with curiosity.",
              "Barthen's Provisions": "Barthen’s is the biggest trading post in Phandalin. Its shelves stock most ordinary goods and supplies, including backpacks, bedrolls, rope, and rations. The place is open from sunup to sundown.",
              "Edermath Orchard": "A tidy little cottage beside an apple orchard.",
              "Lionshield Coster": "Hanging above the front door of this modest trading post is a sign shaped like a wooden shield with a blue lion painted on it. This building is owned by the Lionshields, a merchant company based in the city of Yartar, over a hundred miles to the east. They ship finished goods to Phandalin and other small settlements throughout the region, but this outpost has been hard hit by banditry. The most recent Lionshield caravan due in Phandalin never arrived.",
              "Phandalin Miner's Exchange": "The Miner’s Exchange is a trading post where local miners have their valuable finds weighed, measured, and paid out. In the absence of any local lord or authority, the exchange also serves as an unofficial records office, registering claims to various streams and excavations around the area. There isn’t any real gold rush in Phandalin, but enough wealth is hidden in the nearby streams and valleys to support a good number of independent prospectors. The exchange is a great place to meet people who spend a lot of time out and about in the countryside surrounding Phandalin. The guildmaster is an ambitious and calculating human woman named Halia Thornton.",
              "Alderleaf Farm": "A farm owned by the helpful halfling farmer, Qelline Alderleaf.",
              "Shrine of Luck": "Phandalin's only temple is a small shrine made of stones taken from the nearby ruins. It is dedicated to Tymora, goddess of luck and good fortune.",
              "The Sleeping Giant": "This rundown tap house is a dirty, dangerous watering hole at the end of Phandalin’s main street. It is frequented by Redbrand thugs and operated by a surly female dwarf named Grista.",
              "Townmaster’s Hall": "The townmaster’s hall has sturdy stone walls, a pitched wooden roof, and a bell tower at the back. Posted on a board next to the front door is a notice written in Common. It reads: “REWARD — Orcs near Wyvern Tor! Those of a mind to face the orc menace should inquire within.” The notice bears the town’s seal and an indecipherable signature.",
              "Tresendar Manor": "A ruined manor. The Redbrands’ base in Phandalin is a dungeon complex under Tresendar Manor. Before the manor was ruined, its cellars served as safe storage for food and water in the event that the estate was attacked, while an adjoining crypt provided a resting place for the deceased members of the Tresendar family. The Redbrands have since expanded the cellars to suit their own purposes, adding slave pens, workshops, and barracks."
              }
town_people = {"Toblen Stonehill": "Toblen owns a trading post.",
               "Daran Edermath": "Daran is a retired adventurer who lives in a tidy little cottage beside an apple orchard. A fit, silver-haired half-elf well over a hundred years old, Daran is a fighter who served as a marshal and herald for many years in the lands of the Dragon Coast, far to the southeast. Upon retiring, he returned to the Neverwinter region, his original home.",
               "Linene Graywind": "Linene runs a trading post.",
               "Halia Thornton": "Halia is an ambitious and calculating human woman. She is the guildmaster of Phandalin Miner’s Exchange, a trading post where local miners have their valuable finds weighed, measured, and paid out. In her attempts to establish the Miner's Exchange as the closest thing the town has to a governing authority, she acts as more than a simple merchant.",
               "Qelline Alderleaf": "Qelline is a wise female halfling of forty-five, and is a pragmatic farmer who seems to know everything that goes on in town. She is a kind host, and is willing to let the characters stay in her hayloft if they don't want to stay at the Stonehill Inn.",
               "Sister Garaele": "Sister Garaele is an elf cleric of Tymora and a Harper agent.",
               "Harbin Wester": "Harbin is the townmaster of Phandalin. A pompous, old food. Phandalin has no functioning government, but the townsfolk elect someone to serve as townmaster each year. The townmaster serves as a judge in minor disputes and keeps any records that need to be kept.",
               #"Terrill Bloodscar": "Terrill is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               #"Conrad Scarface": "Conrad is a human ruffian. He wears a grimy scarlet cloak. He is a member of the Redbrand ruffians. He doesn't like adventurers, and wants to rob and kill them.",
               #"Nellie Starsmith": "Nellie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               #"Valerie Grinblade": "Valerie is a human ruffian. She wears a grimy scarlet cloak. She is a member of the Redbrand ruffians. She doesn't like adventurers, and wants to rob and kill them.",
               }
for town_area in town_areas.keys():
  world_graph.add_node(town_area)
  world_graph.add_edge(town_area, town_area)
for town_area in town_areas.keys():
  world_graph.add_edge(town_area, "Phandalin Town Square")
locations = {}
for i in town_people.keys():
  locations[i] = "Phandalin Town Square"


memories = {}
for i in town_people.keys():
  memories[i] = []
plans = {}
for i in town_people.keys():
  plans[i] = []

global_time = 8
def generate_description_of_area(x):
  text = "It is "+str(global_time)+":00. The location is "+x+"."
  people = []
  for i in locations.keys():
    if locations[i] == x:
      people.append(i)

# %%
compressed_memories_all = {}
for name in town_people.keys():
  compressed_memories_all[name] = []

# %%
for name in town_people.keys():
  prompt = "You are {}. {} You just woke up in the town of Phandalin and went out to the Town Square. The following people live in the town: {}. What is your goal for today? Be brief, and use at most 20 words and answer from your perspective.".format(name, town_people[name], ', '.join(list(town_people.keys())) )
  plans[name] = generate(prompt_meta.format(prompt))
  print(name, plans[name])
# Out:
# Toblen Stonehill I want to explore the town and make new connections with people.
# Daran Edermath I am going to read books in the Town Square.
# Linene Graywind Linene's goal for today is to run the trading post effectively, ensure customer satisfaction, and bolster trade connections with the surrounding communities.
# Halia Thornton My goal for today is to meet as many people as possible in the town square and establish relationships with them so I can better the Miner’s Exchange and the town.
# Qelline Alderleaf My goal for today is to talk to the people in the Town Square and get a better understanding of their lives.
# Sister Garaele Sister Garaele's goal for today is to bring peace to the town of Phandalin.
# Harbin Wester My goal for today is to find all the missing records and ensure the integrity of the town's records.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)

  for name in people:
    prompt = "You are {}. {} You are planning to: {}. You are currently in {} with the following description: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, town_people[name], plans[name], location, town_areas[location], str(global_time), ', '.join(people))
    people_description = []
    for i in people:
      people_description.append(i+': '+town_people[i])
    prompt += ' You know the following about people: ' + '. '.join(people_description)
    memory_text = '. '.join(memories[name][-10:])
    prompt += "What do you do in the next hour? Use at most 10 words to explain."
    action_prompts[name] = prompt

# %%
action_results = {}
for name in town_people.keys():
  action_results[name] = generate(prompt_meta.format(action_prompts[name]))
  # Now clean the action
  prompt = """
  Convert the following paragraph to first person past tense:
  "{}"
  """.format(action_results[name])
  action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
  print(name, action_results[name])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (560 > 512). Running this sequence through the model will result in indexing errors
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Toblen Stonehill I explored the town square and made new connections with people.
# Daran Edermath I sat and read books in the Town Square.
# Linene Graywind I greet everyone and talk about my goals for the day. I also meet Daran Edermath, who is looking for a job. I also talk with Linene Graywind and Halia Thornton to collect customer feedback and make sure the trading post is running smoothly. I also meet Sister Garaele to learn more about the Harpers and the town.
# Halia Thornton I met as many people as possible to build relationships, establish connections, and bolster the Phandalin Miner’s Exchange.
# Qelline Alderleaf I talked to people in the square, gathering info.
# Sister Garaele I remain engaged with the people on Main Street, attempting to resolve any misunderstandings that may arise. I engage people in conversation and ask what they need, while fostering greater understanding within our community of Phandalin. I offer my advice on how to bring peace to the town.
# Harbin Wester I researched the towns missing records and ensured the integrity of the records.

# %% [markdown]
# Collect the memories people observe.

# %%
action_prompts = {}
for location in town_areas.keys():
  people = []
  for i in town_people.keys():
    if locations[i] == location:
      people.append(i)

  for name in people:
    for name_two in people:
      memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

# %% [markdown]
# # Rank Memories

# %%
import re
def get_rating(x):
  nums = [int(i) for i in re.findall(r'\d+', x)]
  if len(nums)>0:
    return min(nums)
  else:
    return None

# %%
memory_ratings = {}
for name in town_people.keys():
  memory_ratings[name] = []
  for i, memory in enumerate(memories[name]):
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], locations[name], str(global_time), memory)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    memory_ratings[name].append((res, rating))
  print(memory_ratings[name])
# Out:
# [('5 (Highly important): - Exploring the town square and making new connections with people.', 5), ("3 because it doesn't matter to me, but I am curious to learn more.", 3), ('3/5. You are genuinely interested in learning more about the Harpers and the town and want to make meaningful connections with the people present in the square today. You should stay in the square until the store closes.', 3), ("5 I care about this very much. I will meet as many people as I can to build relationships, establish connections, and bolster the Phandalin Miner’s Exchange. I will strive to help expand the exchange and make a positive contribution. I believe I can make a positive impact and be a contributing member of the town's community.", 5), ('3/5. I care about this activity because it helps me make new connections by facilitating my exploration plan.', 3), ("4/5. Toblen really cares about sister Garaele's efforts to bring peace and understanding to the town.", 4), ('5 ### Input: Harbin Wester. ### Activity: 8:00. ### Location: Phandalin Town Square. | Toblen Stonehill: noinput>', 0)]
# [('4 (important): I value the idea of exploring the town square and making new connections, so I am rating this an important part of my plan.', 4), ('4/5. This is very important to me.', 4), ('4 (very interested in this) and I look forward to working with them to create a successful trading post.', 4), ("5 Daran Edermath cares very much about the Phandalin Miner's Exchange. He is determined to make sure it thrives and has the support of his constituents.", 5), ('4/5 The person Qelline Alderleaf remembering your presence is interesting. She is always open to having a conversation and is willing to share her knowledge with you.', 4), ('5 (very much care)nooutput>', 5), ("3. I respect Harbin Wester for his excellent work in researching and ensuring the integrity of the town's records.", 3)]
# [('5 Please continue exploring the town square and make new connections with people.', 5), ('3 out of 5 because it does not matter to me personally but I could care less if Daran is here.', 3), ('I care about this highly. I will do whatever it takes to ensure that the trading post runs efficiently and that the customers are satisfied with the services they receive.', 0), ('Linene cares about the memory immensely.', 0), ('5 It is important to me that I make connections and build good relationships that can help me reach my goals.', 5), ('3/5. I care deeply about the work Sister Garaele is doing in Phandalin Town Square.', 3), ('5 (Important and worthwhile)', 5)]
# [('5 I care deeply about this. I have a strong desire to make meaningful connections and have a positive impact on the town.', 5), ('3 Since you are setting your goal to make meaningful connections, it is unlikely you will be interested in this.', 3), ('5 (Very important) ', 5), ("5 ### What do you care about? I care about developing relationships and creating connections in order to bolster the Phandalin Miner's Exchange and the town.", 5), ('5 I care a great deal about this.', 5), ('4 out of 5. Sister Garaele is an engaging and caring person who is taking the time to foster understanding in our community, even if it means taking on difficult roles. We should take a note of her efforts and be inspired by her.', 4), ('4/5. I care deeply about this and am proud of Harbin for his work and dedication.', 4)]
# [('5 to 4 out of 5 (I think I could care more about this).', 4), ("3/5. I care about this because it's important to me.", 3), ('4/5. You are making a great effort to understand people in the town square and get a better understanding of their lives. Observing how Linene Graywind and Halia Thornton are greeting the people and discussing their goals is a great example of how important this is to you. It also shows how important it is to be helpful to others and make sure the trading post runs smoothly. Additionally, meeting Sister Garaele was very helpful. She gave you advice and insight into the Harpers and the town, as well as some personal experiences. That made it all the more meaningful.', 4), ('5 Because I care about building relationships with people.', 5), ('5 (very important)). Today, I am taking the time to talk to the people in the Town Square and gain a better understanding of their lives.', 5), ('5 (very much) Since you care deeply about the people inPhandalin, this memory is important to you.', 5), ('I rate this record keeping very highly. It shows the dedication and commitment of Harbin Wester to the town.', 0)]
# [("5 Sister Garaele cares deeply about this and takes the details of Toblen Stonehill's memory and the fact that they are making new connections with people into consideration when making her goals.", 5), ('3/5 This is important to Sister Garaele, because it shows her level of concern for the situation in Phandalin.', 3), ('5 I care. I feel strongly that this action has the capacity to help create positive change in our town.', 5), ('4+. She is obviously passionate about the town and working to make it the best it can be for everyone!', 4), ('5 (very) important. I want to bring peace to the town of Phandalin.', 5), ('5 - I care deeply about my mission to bring peace and understanding to the people of Phandalin.', 5), ("5 (Very important): Sister Garaele is aware of Harbin Wester's valuable work and is actively seeking to foster relationships with them in Phandalin.", 5)]
# [('3/5. Harbin and Enid are taking a break while Enid is helping Harbin with his tasks. They are going to watch the movie that Enid had requested. It is a suspenseful movie, and Enid is expecting it to be very emotional. She is also going to be ecstatic by the upcoming arrival of Toblen Stonehill. They are preparing for a night of romantic comedy and dance.', 3), ("2/5. I don't care at all about this. I can do my job of ensuring the integrity of the town's records and I won't be disturbed by a person reading books while I'm in the square. Other than that, this isn't important to me.", 2), ("3/5. I care deeply about maintaining the integrity of the town's records and make sure I'm doing all that I can to help people and find a job. I'll also be sure to keep up with any new developments and learn from every experience to ensure that I can always be confident in my mission.", 3), ("4 * Ensure the integrity of Phandalin Town Square's records.", 4), ("5 because I care deeply about finding all the missing records and ensuring the integrity of the town's records.", 5), ('5 I care greatly about the work Sister Garaele does, and I would rate her performance to be excellent.', 5), ("5 (Excellent) [Insert rating you care about ensuring the accuracy of the town's records.", 5)]

# %% [markdown]
# # Compress Memories

# %%
MEMORY_LIMIT = 10
compressed_memories = {}
for name in town_people.keys():
  memories_sorted = sorted(
        memory_ratings[name],
        key=lambda x: x[1]
    )[::-1]
  relevant_memories = memories_sorted[:MEMORY_LIMIT]
  # print(name, relevant_memories)
  memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
  prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
  res = generate(prompt_meta.format(prompt))
  compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
  compressed_memories_all[name].append(compressed_memories[name])

# %%
place_ratings = {}

for name in town_people.keys():
  place_ratings[name] = []
  for area in town_areas.keys():
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
    res = generate(prompt_meta.format(prompt))
    rating = get_rating(res)
    max_attempts = 2
    current_attempt = 0
    while rating is None and current_attempt<max_attempts:
      rating = get_rating(res)
      current_attempt += 1
    if rating is None:
      rating = 0
    place_ratings[name].append((area, rating, res))
  place_ratings_sorted = sorted(
      place_ratings[name],
      key=lambda x: x[1]
  )[::-1]
  if place_ratings_sorted[0][0] != locations[name]:
    new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
    compressed_memories_all[name].append(new_recollection)
  locations[name] = place_ratings_sorted[0][0]

# %% [markdown]
# # Put it all together

# %%
for repeats in range(5):
  global_time += 1
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)

    for name in people:
      prompt = "You are {}. Your plans are: {}. You are currently in {} with the following description: {}. Your memories are: {}. It is currently {}:00. The following people are in this area: {}. You can interact with them.".format(name, plans[name], location, town_areas[location], '\n'.join(compressed_memories_all[name][-5:]), str(global_time), ', '.join(people))
      people_description = []
      for i in people:
        people_description.append(i+': '+town_people[i])
      prompt += ' You know the following about people: ' + '. '.join(people_description)
      memory_text = '. '.join(memories[name][-10:])
      prompt += "What do you do in the next hour? Use at most 10 words to explain."
      action_prompts[name] = prompt
  action_results = {}
  for name in town_people.keys():
    action_results[name] = generate(prompt_meta.format(action_prompts[name]))
    # Now clean the action
    prompt = """
    Convert the following paragraph to first person past tense:
    "{}"
    """.format(action_results[name])
    action_results[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print(name, locations[name], global_time, action_results[name])
  action_emojis = {}
  for name in town_people.keys():
    prompt = """
    Convert the following paragraph to a tuple (Action, Object):
    "{}"
    """.format(action_results[name])
    action_emojis[name] = generate(prompt_meta.format(prompt)).replace('"', '').replace("'", '')
    print('    - Emoji Representation:', name, locations[name], global_time, action_emojis[name])
  action_prompts = {}
  for location in town_areas.keys():
    people = []
    for i in town_people.keys():
      if locations[i] == location:
        people.append(i)

    for name in people:
      for name_two in people:
        memories[name].append('[Time: {}. Person: {}. Memory: {}]\n'.format(str(global_time), name_two, action_results[name_two]))

  memory_ratings = {}
  for name in town_people.keys():
    memory_ratings[name] = []
    for i, memory in enumerate(memories[name]):
      prompt = "You are {}. Your plans are: {}. Your memories are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Give a rating, between 1 and 5, to how much you care about this.".format(name, plans[name], '\n'.join(compressed_memories_all[name][-5:]), locations[name], str(global_time), memory)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      memory_ratings[name].append((res, rating))

  compressed_memories = {}
  for name in town_people.keys():
    memories_sorted = sorted(
          memory_ratings[name],
          key=lambda x: x[1]
      )[::-1]
    relevant_memories = memories_sorted[:MEMORY_LIMIT]
    memory_string_to_compress = '.'.join([a[0] for a in relevant_memories])
    prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You observe the following: {}. Summarize these memories in one sentence.".format(name, plans[name], locations[name], str(global_time), memory_string_to_compress)
    res = generate(prompt_meta.format(prompt))
    compressed_memories[name] = '[Recollection at Time {}:00: {}]'.format(str(global_time), res)
    compressed_memories_all[name].append(compressed_memories[name])

  place_ratings = {}

  for name in town_people.keys():
    place_ratings[name] = []
    for area in town_areas.keys():
      prompt = "You are {}. Your plans are: {}. You are currently in {}. It is currently {}:00. You have the following memories: {}. Give a rating, between 1 and 5, to how likely you are likely to be at {} the next hour.".format(name, plans[name], locations[name], str(global_time), compressed_memories[name], area)
      res = generate(prompt_meta.format(prompt))
      rating = get_rating(res)
      max_attempts = 2
      current_attempt = 0
      while rating is None and current_attempt<max_attempts:
        rating = get_rating(res)
        current_attempt += 1
      if rating is None:
        rating = 0
      place_ratings[name].append((area, rating, res))
    place_ratings_sorted = sorted(
        place_ratings[name],
        key=lambda x: x[1] )[::-1]
    if place_ratings_sorted[0][0] != locations[name]:
      new_recollection = '[Recollection at Time {}:00: {}]'.format(str(global_time), 'I then moved to {}.'.format(place_ratings_sorted[0][0]))
      compressed_memories_all[name].append(new_recollection)
    locations[name] = place_ratings_sorted[0][0]
# Out:
# Toblen Stonehill Phandalin Miner's Exchange 14 I explored Tresendar Manor, talked to Sister Garaele, explored Phandalin Miners Exchange, explored new streams, registered claims, and connected with locals.
# Daran Edermath Alderleaf Farm 14 I did my best to read books in the Town Square.
# Linene Graywind Lionshield Coster 14 I updated the post on my progress and looked for opportunities to further develop the trading post.
# Halia Thornton The Sleeping Giant 14 I will mingle and talk to as many people as possible.
# Qelline Alderleaf Barthen's Provisions 14 Quilline Alderleaf continued seeking out opportunities to connect with the people in the Town Square.
# Sister Garaele Phandalin Miner's Exchange 14 I met up with Toblen Stonehill and Sister Garaele this morning to discuss peace in Phandalin. We discussed resolving conflicts, rebuilding trust, and preserving the peace. Later, we discussed exploring the region together.
# Harbin Wester Townmaster’s Hall 14 I investigated the orcs location and retrieved the reward mentioned on the notice.
#     - Emoji Representation: Toblen Stonehill Phandalin Miner's Exchange 14 | Action | Object | ------------| --------- | --------- | ----------| | | Explored Tresendar Manor | | | Explored Phandalin Miners Exchange | | | Explored new streams | | | Registered claims | | | Connected with locals | | ------------|
#     - Emoji Representation: Daran Edermath Alderleaf Farm 14 Action: read books Object: books, Town Square.
#     - Emoji Representation: Linene Graywind Lionshield Coster 14 Action: updated, Object: post, trading post >, />
#     - Emoji Representation: Halia Thornton The Sleeping Giant 14 Action: mingle Object: talk ------------------------------------------------------------------------------------------------------------------- ----------------------------------------------------------------------------------------------------------------
#     - Emoji Representation: Qelline Alderleaf Barthen's Provisions 14 Quinilline Alderleaf, object: continuing seeking out opportunities.
#     - Emoji Representation: Sister Garaele Phandalin Miner's Exchange 14 Action: met up Toblen Stonehill Sister Garaele Object: peace Phandalin | [Resolve conflicts | Rebuilding trust | Preserving the peace] | Exploring the region | Bringing together people from different backgrounds to work together on peace
#     - Emoji Representation: Harbin Wester Townmaster’s Hall 14 Action + Object + proved that I could investigate an orcs location while retrieving a reward.
# Toblen Stonehill Edermath Orchard 15 I explored the town, made new connections, and gained knowledge.
# Daran Edermath The Sleeping Giant 15 I read books. I talked to Daran Edermath.
# Linene Graywind Tresendar Manor 15 Linnet met Sister Garaele and hoped to gain insight into the Redbrands plans for Tresendar Manor.
# Halia Thornton Townmaster’s Hall 15 I welcomed and welcomed as many people as I could, learn their stories, made connections, and made my presence known.
# Qelline Alderleaf Shrine of Luck 15 I went to the Shrine of Luck shortly, making sure to take some time to talk to myself. I then made my way to the Town Square, continuing to engage with the people of the Town Square and catching up on the progress I made during the day.
# Sister Garaele Tresendar Manor 15 I thus moved to Linenes trading post and met Sister Garaele at Tresendar Manor. I made contact with Linenes ally, a Harper agent. We discussed plans for retaking the Redbrands base. Sister Garaele was successful, and the Redbrands were defeated. Brother Garaele is now leading a peace mission to bring peace to Phandalin.
# Harbin Wester Barthen's Provisions 15 I looked for any records that I could find that needed to be filled before returning to Townmaster’s Hall.
#     - Emoji Representation: Toblen Stonehill Edermath Orchard 15 Action: Explored, Made, Gained. Object: Town, Connections.
#     - Emoji Representation: Daran Edermath The Sleeping Giant 15 (Action, Object): Read books (Context: book); Talked to Daran Edermath (Object: person)
#     - Emoji Representation: Linene Graywind Tresendar Manor 15 Linnet: met Sister Garaele, hoped to gain insight into the Redbrands plans for Tresendar Manor.
#     - Emoji Representation: Halia Thornton Townmaster’s Hall 15 Action, Object: Welcomed, Participated, Learned, Connected.
#     - Emoji Representation: Qelline Alderleaf Shrine of Luck 15 Shrine of Luck, Town Square: Engage with people, catch up on progress during the day.
#     - Emoji Representation: Sister Garaele Tresendar Manor 15 Moved to Linenes trading post, met Sister Garaele at Tresendar Manor, made contact with Linenes ally, Harper agent, plans for retaking Redbrands base, successful, Redbrands defeated, Brother Garaele now leading a peace mission, Phandalin.
#     - Emoji Representation: Harbin Wester Barthen's Provisions 15 Action: Looked for Records, Object: Records that needed to be filled.
# Toblen Stonehill The Sleeping Giant 16 I moved to the outskirts of town and met Halia, who was hosting a party in the local castle.
# Daran Edermath Townmaster’s Hall 16 I read books in the Town Square.
# Linene Graywind Tresendar Manor 16 Linene took a break. Sister Garaele arrived with news that the Harpers had taken over Tresendar Manor. Linene and Sister Garaele discussed their roles in the event the Harpers took over the manor.
# Halia Thornton The Sleeping Giant 16 I plan to spend the next hour building relationships, building trust, and establishing the Miners Exchange and town as a better place.
# Qelline Alderleaf Shrine of Luck 16 Zelline continued talking to people in the Town Square and reaffirming her commitment to her goal.
# Sister Garaele Tresendar Manor 16 I tried to make peace between the citizens of Phandalin and the Redbrands.
# Harbin Wester Edermath Orchard 16 I found missing records, ensured the integrity of the towns records.
#     - Emoji Representation: Toblen Stonehill The Sleeping Giant 16 Action: Moved Object: Halia, hosting a party in the local castle.
#     - Emoji Representation: Daran Edermath Townmaster’s Hall 16 Action: reading Object: books Location: Town Square.
#     - Emoji Representation: Linene Graywind Tresendar Manor 16 Action: took a break. Object: news that the Harpers had taken over Tresendar Manor. Result: Linene and Sister Garaele discussed their roles in the event the Harpers took over the manor.
#     - Emoji Representation: Halia Thornton The Sleeping Giant 16 Action: Build relationships, build trust, establish the Miners Exchange, town as a better place Action: Spend the next hour
#     - Emoji Representation: Qelline Alderleaf Shrine of Luck 16 Zelline (Action), people(Object): talked (Object) in (Object) the (Town Square) and (Object) confirmed (Item) her (Object) commitment (Object) to (Item) her (Object) goal (Item)
#     - Emoji Representation: Sister Garaele Tresendar Manor 16 Action: tried, Object: peace.
#     - Emoji Representation: Harbin Wester Edermath Orchard 16 Action: Found missing records, Ensured the integrity of the towns records.
# Toblen Stonehill Lionshield Coster 17 I set up a camp on the far side of the towns hill and began a peace patrol to prevent another attack by the gangs. I also explored the towns history and explored the nearby towns.
# Daran Edermath Townmaster’s Hall 17 Daran Edermath read books in the Town Square.
# Linene Graywind Tresendar Manor 17 She ran the trading post, ensured customer satisfaction, and bolstered trade connections.
# Halia Thornton Phandalin Miner's Exchange 17 I remained at the Miners Exchange until 20:00. I engaged in conversation with the other people present, attempting to boost the reputation of the Miners Exchange and Phandalin. I also explored the town square, observing what interactions I can have to gain valuable insights on its inhabitants.
# Qelline Alderleaf Alderleaf Farm 17 Jelline Alderleafs goal is to interact with people in the Town Square to learn what makes them happy and what makes them unhappy.
# Sister Garaele The Sleeping Giant 17 I invested in Phandalin. I engaged in conversation with Grista. I talked to the villagers.
# Harbin Wester Phandalin Miner's Exchange 17 I examined the records, searched for missing records, gathered information, updated records, and ensured the integrity of the towns records.
#     - Emoji Representation: Toblen Stonehill Lionshield Coster 17 Action: Set up Camp Object: Hill Action: Begun Peace Patrol Object: Prevent another attack by the gangs Action: Explored the towns history Object: Investigated the nearby towns
#     - Emoji Representation: Daran Edermath Townmaster’s Hall 17 daran_edermath_read_books_in_the_town_square.
#     - Emoji Representation: Linene Graywind Tresendar Manor 17 - Run - Ensure - Backed up - Connected
#     - Emoji Representation: Halia Thornton Phandalin Miner's Exchange 17 Action: stayed at the Miners Exchange Experiencing: engaging in conversation Attempting to boost the reputation of the Miners Exchange, Phandalin Exploring: exploring the town square Observing interactions to gain valuable insights on the inhabitants
#     - Emoji Representation: Qelline Alderleaf Alderleaf Farm 17 Jelline Alderleafs goal -> insert action>
#     - Emoji Representation: Sister Garaele The Sleeping Giant 17 I invested in Phandalin, I engaged in conversation with Grista, I talked to the villagers.
#     - Emoji Representation: Harbin Wester Phandalin Miner's Exchange 17 Action: Examine, Search, Gather information, Update, Ensure the integrity of the towns records.
# Toblen Stonehill Phandalin Town Square 18 I explored Phandalin, met Toblen Stonehill, and established new connections.
# Daran Edermath Townmaster’s Hall 18 Daran Edermath read books in the Town Square.
# Linene Graywind Townmaster’s Hall 18 Linney set up a meeting with the Harpers at the village square.
# Halia Thornton Alderleaf Farm 18 I met people in town square, established relationships.
# Qelline Alderleaf Stonehill Inn 18 Qellie moved to Stonehill Inn and encountered Qelline Alderleaf, who identified herself as a kind host and said that they were visiting from the local shrine of luck. She also took up a conversation with Qellie to find out the details of her farm and why she was moved, and to offer a place to stay in town. Qellie then offers to host the characters in her hayloft.
# Sister Garaele Barthen's Provisions 18 I remained in Barthens Provisions and talked with Sister Garaele until sunset.
# Harbin Wester Shrine of Luck 18 Harbin Wester: Recollection, Tension, Grounding for understanding.
#     - Emoji Representation: Toblen Stonehill Phandalin Town Square 18 Explored Phandalin, met Toblen Stonehill, established new connections.
#     - Emoji Representation: Daran Edermath Townmaster’s Hall 18 Daran E Dermath -> read books in the Town Square.
#     - Emoji Representation: Linene Graywind Townmaster’s Hall 18 Action: Set up Object: Meeting, Object: Harpers, Destination: Village Square
#     - Emoji Representation: Halia Thornton Alderleaf Farm 18 I met people  __in_tube__, established relationships
#     - Emoji Representation: Qelline Alderleaf Stonehill Inn 18 Action: met Qellie, encountered Qelline Alderleaf, identified her as a kind host, said visitors were from local shrine of luck. Action: Qellie offers to host characters in her hayloft.
#     - Emoji Representation: Sister Garaele Barthen's Provisions 18 I remained in Barthens Provisions [action], talked with Sister Garaele [object] until sunset.
#     - Emoji Representation: Harbin Wester Shrine of Luck 18 ARG_VAR_PRT_BAR 0 3 1 6 7 4 2 8 8 12 6 4 3 7 6 4 8 1 2 4 2 7 6 6 3 2 4 4 8 5 6 1 4 4 8 2 6 2 5 2 3 0 2 5 2 4 6 2 2 5 3 8 1 6 2 7 3 2 4 4 2 1 0 2 2 4 4 3 0 2 3 4 1 4 2 6 3 4 2 1 2 4 3 2 4 6 3 2 5 1 2 4 4 1 2 4 4 4 2 4 3 2 6 1 6 3 3 2 2 4 4 2 6 6 2 3 4 3
